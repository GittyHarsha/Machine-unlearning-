# %%
# !pip install torch_geometric
# Out:
# Requirement already satisfied: torch_geometric in /usr/local/lib/python3.10/dist-packages (2.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.11.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2024.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2024.12.14)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->torch_geometric) (4.12.2)

# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch.optim import Adam

import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch.optim import Adam

def synthesize_graph_for_class(model, device, target_class, num_samples, graph_data,
                               lr=0.1, steps=800, regularization_weight=1e-4, debug=False):
    model.eval()

    # Extract the original graph data
    node_features = graph_data.x.to(device)  # Node features from the input graph
    edge_index = graph_data.edge_index.to(device)  # Edge indices from the input graph

    # Initialize the optimizer for node features and adjacency matrix
    node_features.requires_grad = True
    adj_matrix = torch.randn(num_samples, num_samples, device=device, requires_grad=True)
    adj_matrix.data = torch.sigmoid(adj_matrix.data)

    optimizer = Adam([node_features, adj_matrix], lr=lr)
    done_mask = torch.zeros(num_samples, dtype=torch.bool, device=device)

    for step in range(steps):
        if done_mask.all():
            if debug:
                print(f"All samples reached target class by step {step}. Stopping early.")
            break

        optimizer.zero_grad()

        # Create graph data structure for PyG model
        edge_index = adj_matrix.nonzero(as_tuple=False).t()  # Update the graph edges from the learned adjacency matrix
        data = Data(x=node_features, edge_index=edge_index)

        # Forward pass through the model
        outputs = model(data)
        class_scores = outputs[:, target_class]
        print(f"Step {step+1}: Class scores for target class: {class_scores.mean().item()}")

        loss = -class_scores.mean() + regularization_weight * (node_features**2).mean()
        loss.backward()
        optimizer.step()

        # Clamp features between [0, 1]
        node_features.data.clamp_(0, 1)

        # Check if the node is classified as target class
        preds = torch.argmax(outputs, dim=1)
        previously_done_count = done_mask.sum().item()
        done_mask = done_mask | (preds == target_class)
        currently_done_count = done_mask.sum().item()

        if debug:
            newly_done = currently_done_count - previously_done_count
            print(f"Step {step+1}/{steps}: {currently_done_count}/{num_samples} nodes done (+{newly_done} this step).")

    if debug and not done_mask.all():
        print(f"Reached max steps without all nodes classified as target class. "
              f"{done_mask.sum().item()} out of {num_samples} done.")

    return node_features.detach(), adj_matrix.detach()

# %%
import torch
from torch_geometric.data import Data

def get_class_samples_from_noise_for_graph(model, device, unlearn_class, data):
    num_classes = 7
    num_samples = data.num_nodes

    # Synthesize graphs for the unlearn_class
    forget_node_features, forget_adj_matrix = synthesize_graph_for_class(
            model=model,
            device=device,
            target_class=unlearn_class,
            num_samples=num_samples,
            graph_data=data,
            lr=0.1,
            steps=500,
            regularization_weight=1e-4,
            debug=True
            )

    # Create Data object for the forget data
    forget_data = Data(x=forget_node_features, edge_index=forget_adj_matrix, y=torch.full((num_samples,), unlearn_class, dtype=torch.long))

    retain_node_features_list = []
    retain_labels_list = []

    # Synthesize graphs for other classes (retain data)
    for c in range(num_classes):
        if c == unlearn_class:
            continue

        # Generate synthetic graph for current class
        class_node_features, class_adj_matrix = synthesize_graph_for_class(
            model=model,
            device=device,
            target_class=c,  # Use class c for retention
            num_samples=num_samples,
            graph_data=data,
            lr=0.1,
            steps=500,
            regularization_weight=1e-4,
            debug=True
        )

        retain_node_features_list.append(class_node_features)

    retain_node_features = torch.cat(retain_node_features_list, dim=0)
    retain_labels = torch.tensor(retain_labels_list, dtype=torch.long)

    retain_data = Data(x=retain_node_features, edge_index=forget_adj_matrix, y=retain_labels)

    return forget_data, retain_data

# %%
from torch_geometric.datasets import Planetoid
from torch_geometric.nn import GCNConv

# Load the CORA dataset
dataset = Planetoid(root='/tmp/Cora', name='Cora')
data = dataset[0]  # Extract the first graph
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
data = data.to(device)
# Example GCN model
class GCN(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(in_channels, 16)
        self.conv2 = GCNConv(16, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)
        return x

# Initialize model and move to device (CPU/GPU)
model = GCN(in_channels=data.num_features, out_channels=dataset.num_classes).to(device)
model.eval()

# Synthesize a graph for a specific class
target_class = 0  # Example target class
num_samples = data.num_nodes  # Using the number of nodes in the original graph
forget_data,retain_data = get_class_samples_from_noise_for_graph(model, device, target_class, data)
# Out:
# Step 1: Class scores for target class: 0.0013795519480481744
# Step 1/500: 0/2708 nodes done (+0 this step).
# Step 2: Class scores for target class: 1.0357791185379028
# Step 2/500: 2708/2708 nodes done (+2708 this step).
# All samples reached target class by step 2. Stopping early.
# Step 1: Class scores for target class: 1.5318753719329834
# Step 1/500: 0/2708 nodes done (+0 this step).
# Step 2: Class scores for target class: 3.4000704288482666
# Step 2/500: 0/2708 nodes done (+0 this step).
# Step 3: Class scores for target class: 5.019963264465332
# Step 3/500: 2708/2708 nodes done (+2708 this step).
# All samples reached target class by step 3. Stopping early.
# Step 1: Class scores for target class: -1.3370870351791382
# Step 1/500: 0/2708 nodes done (+0 this step).
# Step 2: Class scores for target class: 0.6938981413841248
# Step 2/500: 0/2708 nodes done (+0 this step).
# Step 3: Class scores for target class: 1.7264173030853271
# Step 3/500: 0/2708 nodes done (+0 this step).
# Step 4: Class scores for target class: 2.6578943729400635
# Step 4/500: 0/2708 nodes done (+0 this step).
# Step 5: Class scores for target class: 3.4670753479003906
# Step 5/500: 0/2708 nodes done (+0 this step).
# Step 6: Class scores for target class: 4.288353443145752
# Step 6/500: 0/2708 nodes done (+0 this step).
# Step 7: Class scores for target class: 5.2412848472595215
# Step 7/500: 0/2708 nodes done (+0 this step).
# Step 8: Class scores for target class: 6.2446064949035645
# Step 8/500: 2708/2708 nodes done (+2708 this step).
# All samples reached target class by step 8. Stopping early.
# Step 1: Class scores for target class: 2.360231876373291
# Step 1/500: 0/2708 nodes done (+0 this step).
# Step 2: Class scores for target class: 4.239967346191406
# Step 2/500: 0/2708 nodes done (+0 this step).
# Step 3: Class scores for target class: 5.813652515411377
# Step 3/500: 0/2708 nodes done (+0 this step).
# Step 4: Class scores for target class: 7.0836405754089355
# Step 4/500: 2708/2708 nodes done (+2708 this step).
# All samples reached target class by step 4. Stopping early.
# Step 1: Class scores for target class: -1.5776405334472656
# Step 1/500: 0/2708 nodes done (+0 this step).
# Step 2: Class scores for target class: 0.7162924408912659
# Step 2/500: 0/2708 nodes done (+0 this step).
# Step 3: Class scores for target class: 1.9647561311721802
# Step 3/500: 0/2708 nodes done (+0 this step).
# Step 4: Class scores for target class: 3.1074435710906982
# Step 4/500: 0/2708 nodes done (+0 this step).
# Step 5: Class scores for target class: 4.224555492401123
# Step 5/500: 0/2708 nodes done (+0 this step).
# Step 6: Class scores for target class: 5.285091876983643
# Step 6/500: 0/2708 nodes done (+0 this step).
# Step 7: Class scores for target class: 6.2811665534973145
# Step 7/500: 2708/2708 nodes done (+2708 this step).
# All samples reached target class by step 7. Stopping early.
# Step 1: Class scores for target class: 2.057697057723999
# Step 1/500: 0/2708 nodes done (+0 this step).
# Step 2: Class scores for target class: 3.3276028633117676
# Step 2/500: 0/2708 nodes done (+0 this step).
# Step 3: Class scores for target class: 4.330092906951904
# Step 3/500: 0/2708 nodes done (+0 this step).
# Step 4: Class scores for target class: 5.2992777824401855
# Step 4/500: 0/2708 nodes done (+0 this step).
# Step 5: Class scores for target class: 6.178335666656494
# Step 5/500: 0/2708 nodes done (+0 this step).
# Step 6: Class scores for target class: 6.936363220214844
# Step 6/500: 0/2708 nodes done (+0 this step).
# Step 7: Class scores for target class: 7.483002662658691
# Step 7/500: 0/2708 nodes done (+0 this step).
# Step 8: Class scores for target class: 7.967224597930908
# Step 8/500: 0/2708 nodes done (+0 this step).
# Step 9: Class scores for target class: 8.355910301208496
# Step 9/500: 0/2708 nodes done (+0 this step).
# Step 10: Class scores for target class: 8.681418418884277
# Step 10/500: 0/2708 nodes done (+0 this step).
# Step 11: Class scores for target class: 8.971718788146973
# Step 11/500: 0/2708 nodes done (+0 this step).
# Step 12: Class scores for target class: 9.178396224975586
# Step 12/500: 0/2708 nodes done (+0 this step).
# Step 13: Class scores for target class: 9.275406837463379
# Step 13/500: 0/2708 nodes done (+0 this step).
# Step 14: Class scores for target class: 9.356643676757812
# Step 14/500: 0/2708 nodes done (+0 this step).
# Step 15: Class scores for target class: 9.432555198669434
# Step 15/500: 0/2708 nodes done (+0 this step).
# Step 16: Class scores for target class: 9.482100486755371
# Step 16/500: 0/2708 nodes done (+0 this step).
# Step 17: Class scores for target class: 9.527242660522461
# Step 17/500: 0/2708 nodes done (+0 this step).
# Step 18: Class scores for target class: 9.567322731018066
# Step 18/500: 0/2708 nodes done (+0 this step).
# Step 19: Class scores for target class: 9.601973533630371
# Step 19/500: 0/2708 nodes done (+0 this step).
# Step 20: Class scores for target class: 9.633116722106934
# Step 20/500: 0/2708 nodes done (+0 this step).
# Step 21: Class scores for target class: 9.652059555053711
# Step 21/500: 0/2708 nodes done (+0 this step).
# Step 22: Class scores for target class: 9.682784080505371
# Step 22/500: 0/2708 nodes done (+0 this step).
# Step 23: Class scores for target class: 9.702574729919434
# Step 23/500: 0/2708 nodes done (+0 this step).
# Step 24: Class scores for target class: 9.718947410583496
# Step 24/500: 0/2708 nodes done (+0 this step).
# Step 25: Class scores for target class: 9.732819557189941
# Step 25/500: 0/2708 nodes done (+0 this step).
# Step 26: Class scores for target class: 9.735199928283691
# Step 26/500: 0/2708 nodes done (+0 this step).
# Step 27: Class scores for target class: 9.752715110778809
# Step 27/500: 0/2708 nodes done (+0 this step).
# Step 28: Class scores for target class: 9.759673118591309
# Step 28/500: 0/2708 nodes done (+0 this step).
# Step 29: Class scores for target class: 9.765678405761719
# Step 29/500: 0/2708 nodes done (+0 this step).
# Step 30: Class scores for target class: 9.772109031677246
# Step 30/500: 0/2708 nodes done (+0 this step).
# Step 31: Class scores for target class: 9.776728630065918
# Step 31/500: 0/2708 nodes done (+0 this step).
# Step 32: Class scores for target class: 9.780364990234375
# Step 32/500: 0/2708 nodes done (+0 this step).
# Step 33: Class scores for target class: 9.784440040588379
# Step 33/500: 0/2708 nodes done (+0 this step).
# Step 34: Class scores for target class: 9.782963752746582
# Step 34/500: 0/2708 nodes done (+0 this step).
# Step 35: Class scores for target class: 9.790385246276855
# Step 35/500: 0/2708 nodes done (+0 this step).
# Step 36: Class scores for target class: 9.793045997619629
# Step 36/500: 0/2708 nodes done (+0 this step).
# Step 37: Class scores for target class: 9.795661926269531
# Step 37/500: 0/2708 nodes done (+0 this step).
# Step 38: Class scores for target class: 9.798996925354004
# Step 38/500: 0/2708 nodes done (+0 this step).
# Step 39: Class scores for target class: 9.796407699584961
# Step 39/500: 0/2708 nodes done (+0 this step).
# Step 40: Class scores for target class: 9.801634788513184
# Step 40/500: 0/2708 nodes done (+0 this step).
# Step 41: Class scores for target class: 9.799195289611816
# Step 41/500: 0/2708 nodes done (+0 this step).
# Step 42: Class scores for target class: 9.802308082580566
# Step 42/500: 0/2708 nodes done (+0 this step).
# Step 43: Class scores for target class: 9.802321434020996
# Step 43/500: 0/2708 nodes done (+0 this step).
# Step 44: Class scores for target class: 9.803099632263184
# Step 44/500: 0/2708 nodes done (+0 this step).
# Step 45: Class scores for target class: 9.803609848022461
# Step 45/500: 0/2708 nodes done (+0 this step).
# Step 46: Class scores for target class: 9.803609848022461
# Step 46/500: 0/2708 nodes done (+0 this step).
# Step 47: Class scores for target class: 9.805938720703125
# Step 47/500: 0/2708 nodes done (+0 this step).
# Step 48: Class scores for target class: 9.806746482849121
# Step 48/500: 0/2708 nodes done (+0 this step).
# Step 49: Class scores for target class: 9.807723045349121
# Step 49/500: 0/2708 nodes done (+0 this step).
# Step 50: Class scores for target class: 9.808730125427246
# Step 50/500: 0/2708 nodes done (+0 this step).
# Step 51: Class scores for target class: 9.806199073791504
# Step 51/500: 0/2708 nodes done (+0 this step).
# Step 52: Class scores for target class: 9.809379577636719
# Step 52/500: 0/2708 nodes done (+0 this step).
# Step 53: Class scores for target class: 9.810912132263184
# Step 53/500: 0/2708 nodes done (+0 this step).
# Step 54: Class scores for target class: 9.811308860778809
# Step 54/500: 0/2708 nodes done (+0 this step).
# Step 55: Class scores for target class: 9.810256004333496
# Step 55/500: 0/2708 nodes done (+0 this step).
# Step 56: Class scores for target class: 9.811960220336914
# Step 56/500: 2708/2708 nodes done (+2708 this step).
# All samples reached target class by step 56. Stopping early.
# Step 1: Class scores for target class: -0.9002142548561096
# Step 1/500: 0/2708 nodes done (+0 this step).
# Step 2: Class scores for target class: -0.155393585562706
# Step 2/500: 0/2708 nodes done (+0 this step).
# Step 3: Class scores for target class: 0.2743666172027588
# Step 3/500: 0/2708 nodes done (+0 this step).
# Step 4: Class scores for target class: 0.3098273277282715
# Step 4/500: 0/2708 nodes done (+0 this step).
# Step 5: Class scores for target class: 0.3914971649646759
# Step 5/500: 0/2708 nodes done (+0 this step).
# Step 6: Class scores for target class: 1.0454319715499878
# Step 6/500: 0/2708 nodes done (+0 this step).
# Step 7: Class scores for target class: 1.9812031984329224
# Step 7/500: 0/2708 nodes done (+0 this step).
# Step 8: Class scores for target class: 3.2391510009765625
# Step 8/500: 0/2708 nodes done (+0 this step).
# Step 9: Class scores for target class: 4.6756792068481445
# Step 9/500: 0/2708 nodes done (+0 this step).
# Step 10: Class scores for target class: 6.191253185272217
# Step 10/500: 0/2708 nodes done (+0 this step).
# Step 11: Class scores for target class: 7.643126964569092
# Step 11/500: 2708/2708 nodes done (+2708 this step).
# All samples reached target class by step 11. Stopping early.

# %%
print(retain_data)
# Out:
# Data(x=[16248, 1433], edge_index=[2708, 2708], y=[0])

# %%
print(forget_data)
# Out:
# Data(x=[2708, 1433], edge_index=[2708, 2708], y=[2708])
